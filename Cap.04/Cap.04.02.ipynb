# %% [markdown]
# # Creating FastAPI

# %% [markdown]
# <b> IMPORTANT NOTE! </b>
#
# This notebook is only used for notation purposes. The actual code is in the `main.py` file.
#
# Run it on your local IDE.

# %% [markdown]
# ### Files:
#
# 1. Main: Initialize the api, call functions and receive parameters and pipeline
# 2. Star properties: will receive the star characteristics input
# 3. Star types: Dictionary to classify each kind of star

# %% [markdown]
# ### Step 1
# * Download joblib from previous chapter
# * Add it on local folder with the .py files and requirements.txt

# %% [markdown]
# ### Step 2
#
# 1. Recommended use of python virtual enviroment

# %%
# Open Terminal on your IDE and Run the following code to create the enviroment:
python -m venv star_type_api

# %% [markdown]
# * Activate the enviroment (check accordingly to your IDE and OS how to
# activate it, the commands may be different from one to another).
#
# * <b>Your terminal will look like this:<br>
# (star_type_api)$ </b>

# %% [markdown]
# 2. Install requirements (navigate the terminal to the project folder then run the code below)

# %%
python -m pip install -r requirements.txt

# %% [markdown]
# 3. Run the web aplication with

# %%
uvicorn main:app

# %% [markdown]
# 4. Open the link

# %% [markdown]
# ![Pasted image.png](data:image/png;base64,...)

# %% [markdown]
# 5. On your browser change your link ending to ''/docs'' example ''127.0.0.1:8000/docs''
#
#    Then on "Post" click on Try it out

# %% [markdown]
# ![Pasted image (2).png](data:image/png;base64,...)

# %% [markdown]
# 6. Now you can change the values from an known start and check if the model is accurate
#
#  Example (This is Betegeulse star data that i got from wikipedia):
#
# * temp : 3600
# * lum: 65000
# * radius: 640
# * abs_mag: -5.85
#
#  It should return an Hyper giant

# %% [markdown]
# ![Pasted image (3).png](data:image/png;base64,...)
